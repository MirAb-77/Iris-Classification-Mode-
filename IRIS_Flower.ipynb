# %% [markdown]
# <!-- # <span style="color:#FFFFFF; font-size: 0%;">1 | Introduction</span>
# <div style="border-radius: 0px; background-color: #112241; text-align:center;">
#     <h4 style="color: white; padding: 1.5rem; font-size: 19px"><b>1 | INTRODUCTION</b></h4>
# </div>
# <!-- <br> -->
#
# <div style="display: flex; flex-direction: row; align-items: center;">
#     <div style="flex : 0; margin-top: 10px;">
#         <img src="https://wallpaperaccess.com/full/2355536.jpg" alt="Image" style="max-width: 400px; max-height540px;" />
#     </div>
#     <div style="flex: 1; margin-left: 26px; margin-top: 7px">
#         <h1><b>Data Alchemy: Iris Flower Classification 🔍✨</b></h1>

# %% [markdown]
# # The Iris Flower Data Set
#
# The **Iris flower data set** or **Fisher's Iris data set** is a multivariate data set introduced by the British statistician, eugenicist, and biologist **Ronald Fisher** in his 1936 paper *The use of multiple measurements in taxonomic problems* as an example of linear discriminant analysis【[1](https://en.wikipedia.org/wiki/Iris_flower_data_set#:~:text=The%20Iris%20flower%20data%20set,example%20of%20linear%20discriminant%20analysis.)】. It is sometimes called **Anderson's Iris data set** because **Edgar Anderson** collected the data to quantify the morphologic variation of Iris flowers of three related species【[2](https://en.wikipedia.org/wiki/Iris_flower_data_set#:~:text=The%20Iris%20flower%20data%20set,example%20of%20linear%20discriminant%20analysis.)】.
#
# Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus"【[3](https://en.wikipedia.org/wiki/Iris_flower_data_set#:~:text=The%20Iris%20flower%20data%20set,example%20of%20linear%20discriminant%20analysis.)】. Fisher's paper was published in the journal, the **Annals of Eugenics**, creating controversy about the continued use of the Iris dataset for teaching statistical techniques today.
#
# The data set consists of `150` records and `50` samples under 5 attributes from each of three species(Class) of Iris (`Iris setosa`, `Iris virginica` and `Iris versicolor`). Four features were measured from each sample: the `length` and the `width` of the `sepals` and `petals`, in centimeters(Petal Length, Petal Width, Sepal Length, Sepal width). Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.You can download it [here](https://www.kaggle.com/datasets/arshid/iris-flower-dataset).

# %% [markdown]
# ![https://miro.medium.com/max/2550/0*GVjzZeYrir0R_6-X.png](https://miro.medium.com/max/2550/0*GVjzZeYrir0R_6-X.png)

# %% [markdown]
# > |Variable| Description|
#  |:-------------|:-------------|
#  |sepal length	| <b>the length of the sepals in cm|
#  |sepal width  | <b> the width of the sepals in cm|
#  |petal length    | <b>the length of the petal in cm|
#  |petal width     | <b>the width of the petal in cm|
#  |species    | <b>three Class of Iris (Iris setosa, Iris virginica and Iris versicolor)|

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> Importing Libraries 📚</p></div>

# %%
# Loading, Preprocessing, Analysis Libraries
import numpy as np
import pandas as pd

# Visulaiztion Libraries
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %matplotlib inline


# Model Training And Testing libraries
from sklearn.model_selection import train_test_split

# Model Algorithms Libraries
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB

# Pre-Processing Libraries
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder

# Metrics & Hyper Parameter Libraries
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc, confusion_matrix, recall_score, accuracy_score, precision_score, f1_score, classification_report, f1_score, roc_curve 
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV

# Best Features Selection For Each Category Libraries
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2

# Profiling Libraries
from ydata_profiling import ProfileReport
import os

# Library For Model Comparison
from sklearn.model_selection import KFold

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 1. | DataSet Exploration🔍</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.1 | Importing Dataset</p></div>

# %%
iris = pd.read_csv(r"D:\Projects\Python\CodeSoft Internship\Iris_Project\IRIS.csv")

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.2 | Profile Report</p></div>

# %%
flower_pf = ProfileReport(iris, title = 'Flower(Iris) DataSet Report', explorative = True)
flower_pf
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-31 10:16:45.791096&quot;&gt;&lt;title&gt;Flower(Iris) DataSet Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.3 | Head & Tail </p></div>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.4 | Shape & Info</p></div>

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.5 | Identifying Missing Values</p></div>

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.6 | Duplicate Rows</p></div>

# %%
flower.duplicated().any()
# Out:
# True

# %%
# Identify duplicates
duplicates = iris[iris.duplicated(keep=False)]
print("All duplicate rows (including the first occurrence):")
duplicates
# Out:
# All duplicate rows (including the first occurrence):
#      sepal_length  sepal_width  petal_length  petal_width         species
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
# Print only the duplicate rows (excluding the first occurrence)
dup = iris[iris.duplicated()]
print("Duplicate rows (excluding the first occurrence):")
dup
# Out:
# Duplicate rows (excluding the first occurrence):
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica
#
#      is_duplicate
# 34              1
# 37              1
# 142             1

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.7 | Statistical Summary</p></div>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.856463     3.055782      3.780272     1.208844
# std        0.829100     0.437009      1.759111     0.757874
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include = 'object')
# Out:
#                 species
# count               147
# unique                3
# top     Iris-versicolor
# freq                 50

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.9 | Iris  Features Count</p></div>

# %% [markdown]
# #### Saving Counts In Excel FIle

# %%
def percent_counts(df, feature):
    total = df[feature].value_counts(dropna=False)
    percent = round(df[feature].value_counts(dropna=False, normalize=True) * 100, 2)
    percent_count = pd.concat([total, percent], keys=['Total', 'Percentage'], axis=1)
    return percent_count

# Assuming 'iris' is your DataFrame
# Construct the full file path
file_path = r'D:\Projects\Python\CodeSoft Internship\Iris_Project\Iris_Counts.xlsx'

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(file_path, engine='xlsxwriter')

for col in iris.columns:
    # Apply percent_counts function to each column and save to Excel
    counts = percent_counts(iris, col)
    counts.to_excel(writer, sheet_name=col)

# Close the Pandas Excel writer to finalize the writing process.
writer.close()
print("File Saved")
# Out:
# File Saved

# %%
percent_counts(iris, 'species')
# Out:
#                  Total  Percentage
# Iris-versicolor     50       34.01
# Iris-virginica      49       33.33
# Iris-setosa         48       32.65

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 1.10 | Continuous and Categorical Variables</p></div>

# %%
continuous_values = []
categorical_values = []

for column in iris.columns:
    if iris[column].dtype == 'int64' or iris[column].dtype == 'float64':
        continuous_values.append(column)
    else:
        categorical_values.append(column)
        
        
print("Continuous Columns", continuous_values)
print("\nCategorical Columns", categorical_values)
# Out:
# Continuous Columns ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#
# Categorical Columns ['species']

# %%
dict = {}
for i in list(iris.columns):
    dict[i] = iris[i].value_counts().shape[0]

pd.DataFrame(dict,index=["unique count"]).transpose()
# Out:
#               unique count
# sepal_length            35
# sepal_width             23
# petal_length            43
# petal_width             22
# species                  3

# %% [markdown]
# ## Dataset Exploration Insights 📝
#
# - The dataset contains **150 entries** and `5 columns`.
# - There are **no missing values** in any of the columns.
# - **Duplicate rows** have been identified, with `two occurrences of the same entry in rows 34 and 37`.
#
# - The `species` column has **3 unique values**: 'Iris-setosa', 'Iris-versicolor', and 'Iris-virginica', with the most frequent species being 'Iris-versicolor'.
#
# - The distribution of instances among species is as follows:
#
# |            | Count |
# |------------|-------|
# | Iris-setosa     | 35    |
# | Iris-versicolor | 23    |
# | Iris-virginica  | 43    |
#
# These insights provide a comprehensive overview of the dataset, including basic statistics, missing values, duplicates, and the distribution of target classes.

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b>2. | Visualizations 👓</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 2.1 | Plotting  Species </p></div>

# %%
# Assuming 'iris' is your DataFrame
colors = ["#9370DB", "#ADD8E6", "#98FB98"] # Adjust colors as needed

# Calculate the percentage of each species
l = list(iris['species'].value_counts())
circle = [l[1] / sum(l) * 100, l[2] / sum(l) * 100, l[0] / sum(l) * 100]

# Create subplots
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Pie chart
plt.subplot(1, 2, 1)
plt.pie(circle, labels=['Iris-virginica', 'Iris-Setosa', 'Iris-Versicolor'], autopct='%1.1f%%', startangle=90,
        explode=(0, 0, 0.1), colors=colors, wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'antialiased': True})
plt.title('Species %')

# Count plot
plt.subplot(1, 2, 2)
sns.countplot(x='species', data=iris, palette=colors)
plt.title('Species')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 2.2  | Numerical Features Plotting</p></div>

# %%
# Assuming continuous_values is the updated list of continuous columns ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
continuous_values = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# Create subplots with 5 rows and 2 columns
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(19, 17))

# Define colors for plots
colors = ['#4D3425', '#E4512B', '#5A9BD4', '#FFD700']  

# Plot histograms for each column
for i, col in enumerate(continuous_values):
    plt.subplot(2, 2, i + 1)  # Adjust subplot index
    current_color = colors[i % len(colors)]  
    sns.histplot(iris[col], kde=True, bins=30, color=current_color, edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,10))
     
# Adding the subplot at the specified
# grid position
plt.subplot(221)
graph('sepal_length')
 
plt.subplot(222)
graph('sepal_width')
 
plt.subplot(223)
graph('petal_length')
 
plt.subplot(224)
graph('petal_width')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       3 # Adding the subplot at the specified
#       4 # grid position
#       5 plt.subplot(221)
# ----> 6 graph('sepal_length')
#       8 plt.subplot(222)
#       9 graph('sepal_width')
#
# NameError: name 'graph' is not defined

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 2.3 | Correlation  of Numerical Features</p></div>

# %%
df_corr= iris[continuous_values].corr()
df_corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109321      0.871305     0.817058
# sepal_width      -0.109321     1.000000     -0.421057    -0.356376
# petal_length      0.871305    -0.421057      1.000000     0.961883
# petal_width       0.817058    -0.356376      0.961883     1.000000

# %%
plt.figure(figsize=(19,7))
sns.heatmap(df_corr, annot = True)
plt.title('Correlation Matrix of Continuous Variables')
plt.show()

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 2.4 | Distribution of Iris Species Within Each Feature</p></div>

# %%
# Create individual subplots for each species
fig, axes = plt.subplots(1, 3, figsize=(11, 5))

# Plot histograms for petal_length, petal_width, and sepal_length for each species
for i, species in enumerate(iris['species'].unique()):
    species_data = iris[iris['species'] == species]
    sns.histplot(species_data["petal_length"], kde=True, color="skyblue", bins=20, ax=axes[i], alpha=0.9)  # Increase opacity
    sns.histplot(species_data["petal_width"], kde=True, color="purple", bins=20, ax=axes[i], alpha=0.9)  # Increase opacity
    sns.histplot(species_data["sepal_length"], kde=True, color="green", bins=20, ax=axes[i], alpha=0.9)  # Increase opacity
    axes[i].set_title(species)
    axes[i].set_xlabel("Length")
    axes[i].set_ylabel("Frequency")
    axes[i].legend(["Petal Length", "Petal Width", "Sepal Length"])

# Adjust layout
plt.tight_layout()



# Show the plots
plt.show()

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 3. |  Feature Engineering⚙️</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 3.1  | Outlier Detection & Removal</p></div>

# %%
def outlier_detect(df, col):
    q1_col = Q1[col]
    iqr_col = IQR[col]
    q3_col = Q3[col]
    return df[((df[col] < (q1_col - 1.5 * iqr_col)) |(df[col] > (q3_col + 1.5 * iqr_col)))]

# ---------------------------------------------------------
def outlier_detect_normal(df, col):
    m = df[col].mean()
    s = df[col].std()
    return df[((df[col]-m)/s).abs()>3]

# ---------------------------------------------------------
def lower_outlier(df, col):
    q1_col = Q1[col]
    iqr_col = IQR[col]
    q3_col = Q3[col]
    lower = df[(df[col] < (q1_col - 1.5 * iqr_col))]
    return lower

# ---------------------------------------------------------
def upper_outlier(df, col):
    q1_col = Q1[col]
    iqr_col = IQR[col]
    q3_col = Q3[col]
    upper = df[(df[col] > (q3_col + 1.5 * iqr_col))]
    return upper

# ---------------------------------------------------------
def replace_upper(df, outlier):
    for col in df.columns:
        if np.issubdtype(df[col].dtype, np.number):
            upper = df[col].quantile(0.75) + 1.5 * (df[col].quantile(0.75) - df[col].quantile(0.25))
            tmp = df[col].copy()
            df.loc[tmp > upper, col] = upper

def replace_lower(df, outlier):
    for col in df.columns:
        if np.issubdtype(df[col].dtype, np.number):
            lower = df[col].quantile(0.25) - 1.5 * (df[col].quantile(0.75) - df[col].quantile(0.25))
            tmp = df[col].copy()
            df.loc[tmp < lower, col] = lower

# ---------------------------------------------------------
# Writing Formulas For Upper & Lower Quartiles
Q1 = iris.quantile(0.25, numeric_only=True)
Q3 = iris.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1

for i in range(len(continuous_values)):
    print("IQR => {}: {}".format(continuous_values[i], outlier_detect(iris, continuous_values[i]).shape[0]))
    print("Z_Score => {}: {}".format(continuous_values[i], outlier_detect_normal(iris, continuous_values[i]).shape[0]))
    print("********************************")

    
for i in range(len(continuous_values)):
    print("*********************** {} ***********************\n".format(continuous_values[i]))
    print("lower outlier: {} ****** upper outlier: {}\n".format(lower_outlier(iris, continuous_values[i]).shape[0], upper_outlier(iris, continuous_values[i]).shape[0]))
    plt.figure(figsize=(6, 4))  # Adjust the figsize here to reduce the graph size
    plt.subplot(2,1,1)
    iris[continuous_values[i]].plot(kind='box', subplots=True, sharex=False, vert=False)
    plt.subplot(2,1,2)
    iris[continuous_values[i]].plot(kind='density', subplots=True, sharex=False)
    plt.show()
# Out:
# IQR => sepal_length: 0
# Z_Score => sepal_length: 0
# ********************************
# IQR => sepal_width: 4
# Z_Score => sepal_width: 1
# ********************************
# IQR => petal_length: 0
# Z_Score => petal_length: 0
# ********************************
# IQR => petal_width: 0
# Z_Score => petal_width: 0
# ********************************
# *********************** sepal_length ***********************
#
# lower outlier: 0 ****** upper outlier: 0
# *********************** sepal_width ***********************
#
# lower outlier: 1 ****** upper outlier: 3
# *********************** petal_length ***********************
#
# lower outlier: 0 ****** upper outlier: 0
# *********************** petal_width ***********************
#
# lower outlier: 0 ****** upper outlier: 0

# %%
outlier = []
for i in range(len(continuous_values)):
    if outlier_detect(iris[continuous_values],continuous_values[i]).shape[0] !=0:
        outlier.append(continuous_values[i])

print("Numerical Variables With Outlier Values : ")
outlier
# Out:
# Numerical Variables With Outlier Values :
# ['sepal_width']

# %%
for i in range(len(outlier)):
    replace_upper(iris, outlier[i]) 
    
print("\n********************************\n")
for i in range(len(outlier)):
    replace_lower(iris, outlier[i])
# Out:
# ********************************

# %%
outlier = []
for i in range(len(continuous_values)):
    if outlier_detect(iris[continuous_values],continuous_values[i]).shape[0] !=0:
        outlier.append(continuous_values[i])

print("Numerical Variables With Outlier Values : ")
outlier
# Out:
# Numerical Variables With Outlier Values :
# []

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 3.2 | Label Encoding</p></div>

# %%
# Create a LabelEncoder object
le = LabelEncoder()
df1 = iris.copy(deep=True)
df1['species'] = le.fit_transform(df1['species'])

df1.tail(7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 143           6.8          3.2           5.9          2.3        2
# 144           6.7          3.3           5.7          2.5        2
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 3.3 | Normalization</p></div>

# %%
# Create scaler objects
mms = MinMaxScaler()  # For Min-Max scaling (Normalization)
df2 = df1.copy(deep=True)

# Apply scaling using a loop
for col in continuous_values:
    df2[col] = mms.fit_transform(df2[[col]]) 

df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0      0.222222     0.625000      0.067797     0.041667        0
# 1      0.166667     0.416667      0.067797     0.041667        0
# 2      0.111111     0.500000      0.050847     0.041667        0
# 3      0.083333     0.458333      0.084746     0.041667        0
# 4      0.194444     0.666667      0.067797     0.041667        0

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 4. |  Data Separation 🪓</p></div>

# %%
# Extract the selected features from the DataFrame
features = df2.drop(columns=['species'], axis=1).values
target = df2['species'].values

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=42)

print("Training set features shape:", x_train.shape)
print("Testing set features shape:", x_test.shape)
print("Training set target shape:", y_train.shape)
print("Testing set target shape:", y_test.shape)
# Out:
# Training set features shape: (120, 4)
# Testing set features shape: (30, 4)
# Training set target shape: (120,)
# Testing set target shape: (30,)

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 4.1 | Saving Testing Features & Target</p></div>

# %%
import os
# Save the testing features
x_test_path = r'D:\Projects\Python\CodeSoft Internship\Iris_Project\x_test.csv'
if os.path.exists(x_test_path):
    os.remove(x_test_path)
x_test_df = pd.DataFrame(data=x_test)
x_test_df.to_csv(x_test_path, index=False)
print("Testing features saved successfully!")

# Save the testing target
y_test_path = r'D:\Projects\Python\CodeSoft Internship\Iris_Project\y_test.csv'
if os.path.exists(y_test_path):
    os.remove(y_test_path)
y_test_df = pd.DataFrame(data=y_test, columns=['species'])
y_test_df.to_csv(y_test_path, index=False)
print("Testing target saved successfully!")
# Out:
# Testing features saved successfully!
# Testing target saved successfully!

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 5. |  Model Training 🛠️</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 5.1 | Functions For Training & Evaluation</p></div>

# %%
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

def evaluate_classifier(classifier, x_test, y_test):
    # Confusion Matrix
    y_pred = classifier.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)
    class_names = np.unique(y_test)
    plot_confusion_matrix(cm, class_names)

    # Classification Report
    print("\nClassification Report:\n", classification_report(y_test, y_pred))

    # ROC Curve (not applicable for multi-class classification)

def evaluate_model(classifier, x_train, y_train, x_test, y_test):
    classifier.fit(x_train, y_train)
    prediction = classifier.predict(x_test)

    # Calculate metrics
    accuracy = accuracy_score(y_test, prediction)
    precision = precision_score(y_test, prediction, average='weighted')
    recall = recall_score(y_test, prediction, average='weighted')
    f1 = f1_score(y_test, prediction, average='weighted')
    
    print("Training Accuracy: {:.2%}".format(classifier.score(x_train, y_train)))
    print("Test Accuracy: {:.2%}".format(accuracy))
    print("Precision: {:.2%}".format(precision))
    print("Recall: {:.2%}".format(recall))
    print("F1 Score: {:.2%}".format(f1))
    

    # Evaluation
    evaluate_classifier(classifier, x_test, y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import HistGradientBoostingClassifier

rf = RandomForestClassifier()
mlp = MLPClassifier(max_iter=1000)
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
naive_bayes = GaussianNB()

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 6. |  Model Evaluation 📊</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.1 | Naive Bayes</p></div>

# %%
model0 = evaluate_model(naive_bayes, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 95.00%
# Test Accuracy: 100.00%
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.2 | KNN</p></div>

# %%
model1 = evaluate_model(knn, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 96.67%
# Test Accuracy: 100.00%
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.3 | Logistic Regression</p></div>

# %%
model2 = evaluate_model(lr, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 92.50%
# Test Accuracy: 96.67%
# Precision: 96.94%
# Recall: 96.67%
# F1 Score: 96.64%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.4 | SVC</p></div>

# %%
model5 = evaluate_model(svm, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 97.50%
# Test Accuracy: 100.00%
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.5 | MLP Classifier</p></div>

# %%
model4 = evaluate_model(mlp, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 97.50%
# Test Accuracy: 96.67%
# Precision: 96.94%
# Recall: 96.67%
# F1 Score: 96.64%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.6 | Random Forest classifier</p></div>

# %%
model = evaluate_model(rf, x_train, y_train, x_test, y_test)
# Out:
# Training Accuracy: 100.00%
# Test Accuracy: 100.00%
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.7 | Mean Accuracy for Each Model</p></div>

# %%
models = [rf, mlp, lr, knn, svm, naive_bayes]

# Compute mean accuracy for each model using cross-validation
mean_accuracies = []
for model in models:
    mean_accuracy = cross_val_score(model, x_train, y_train, cv=10, scoring='accuracy').mean()
    mean_accuracies.append(mean_accuracy)

# Calculate overall mean accuracy
overall_mean_accuracy = sum(mean_accuracies) / len(mean_accuracies)

# Report results
print("\nMean Accuracy for Each Model:")
for i, model in enumerate(models):
    print(f"{model.__class__.__name__}: {mean_accuracies[i]}")
print(f"\n\nOverall Mean Accuracy: {overall_mean_accuracy}")
# Out:
# Mean Accuracy for Each Model:
# RandomForestClassifier: 0.9249999999999998
# MLPClassifier: 0.9583333333333334
# LogisticRegression: 0.9083333333333332
# KNeighborsClassifier: 0.9333333333333332
# SVC: 0.9333333333333332
# GaussianNB: 0.9416666666666667
#
#
# Overall Mean Accuracy: 0.9333333333333332

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"></b> 6.8 |CV Scores of Models</p></div>

# %%
# Compute cross-validation score for each model
cv_scores = {}
for model in models:
    scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
    cv_scores[model.__class__.__name__] = scores
    mean_score = scores.mean()

# Report cross-validation scores
for model_name, scores in cv_scores.items():
    print("-" * 50)
    print(f"{model_name}: \nCross-Validation Scores: {scores}")
    print(f"{model_name}: \nMean Score: {mean_score}")
# Out:
# --------------------------------------------------
# RandomForestClassifier:
# Cross-Validation Scores: [0.95833333 1.         0.875      1.         0.95833333]
# RandomForestClassifier:
# Mean Score: 0.9416666666666668
# --------------------------------------------------
# MLPClassifier:
# Cross-Validation Scores: [0.95833333 1.         0.83333333 1.         1.        ]
# MLPClassifier:
# Mean Score: 0.9416666666666668
# --------------------------------------------------
# LogisticRegression:
# Cross-Validation Scores: [0.83333333 1.         0.83333333 0.95833333 0.91666667]
# LogisticRegression:
# Mean Score: 0.9416666666666668
# --------------------------------------------------
# KNeighborsClassifier:
# Cross-Validation Scores: [0.95833333 1.         0.79166667 1.         0.95833333]
# KNeighborsClassifier:
# Mean Score: 0.9416666666666668
# --------------------------------------------------
# SVC:
# ...

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 7. |  Models Comparison 📈</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 7.1 | Metrics Comparison</p></div>

# %%
from 
rf = RandomForestClassifier()
mlp = MLPClassifier(max_iter=1000)
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
naive_bayes = GaussianNB()

models = [rf, mlp, lr, knn, svm, naive_bayes]
# Define evaluation metrics
metrics = {
    'Test Accuracy': [],
    'Train Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1 Score': [],
    'Cross-Validation Mean Score': [],
    'Cross-Validation Scores': []
}

# Calculate metrics for each model
for model in models:
    # Test accuracy
    test_accuracy = accuracy_score(y_test, model.predict(x_test))
    metrics['Test Accuracy'].append(test_accuracy)
    
    # Train accuracy
    train_accuracy = accuracy_score(y_train, model.predict(x_train))
    metrics['Train Accuracy'].append(train_accuracy)
    
    # Precision
    precision = precision_score(y_test, model.predict(x_test), average='weighted')
    metrics['Precision'].append(precision)
    
    # Recall
    recall = recall_score(y_test, model.predict(x_test), average='weighted')
    metrics['Recall'].append(recall)
    
    # F1 score
    f1 = f1_score(y_test, model.predict(x_test), average='weighted')
    metrics['F1 Score'].append(f1)
    
    # Cross-validation scores
    cv_scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
    metrics['Cross-Validation Scores'].append(cv_scores.tolist())
    
    # Cross-validation mean score
    cv_mean_score = np.mean(cv_scores)
    metrics['Cross-Validation Mean Score'].append(cv_mean_score)

# Create a DataFrame from the metrics
metrics_df = pd.DataFrame(metrics, index=[model.__class__.__name__ for model in models])

# Display the DataFrame
print("\nMetrics for Each Model:")
metrics_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 rf = RandomForestClassifier()
#       2 mlp = MLPClassifier(max_iter=1000)
# ----> 3 lr = LogisticRegression()
#       4 knn = KNeighborsClassifier()
#       5 svm = SVC()
#
# NameError: name 'LogisticRegression' is not defined

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 7.2 | Metrics Heatmap</p></div>

# %%
# Calculate summary statistics for cross-validation scores
cv_mean_scores = metrics_df['Cross-Validation Scores'].apply(np.mean)
cv_std_scores = metrics_df['Cross-Validation Scores'].apply(np.std)

# Create a new DataFrame with summary statistics
cv_summary_df = pd.DataFrame({'Cross-Validation Mean Score': cv_mean_scores, 'Cross-Validation Std Score': cv_std_scores})

# Combine the summary statistics with other metrics
combined_metrics_df = pd.concat([metrics_df.drop(columns=['Cross-Validation Scores']), cv_summary_df], axis=1)

# Plot a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(combined_metrics_df, annot=True, cmap='coolwarm', fmt='.4f', cbar=True)
plt.title('Comparison of Models')
plt.xlabel('Metrics')
plt.ylabel('Models')
plt.xticks()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 7.3 | Finding Best Model</p></div>

# %%
# Define models with best hyperparameters
models = {
    'Random Forest': rf,
    'MLP': mlp,
    'Logistic Regression': lr,
    'KNN': knn,
    'SVM': svm,
    'Naive Bayes': GaussianNB()
}

# Initialize a list to store results
results = []

# Function to evaluate models
def evaluate_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train)
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    train_accuracy = accuracy_score(y_train, y_pred_train)
    test_accuracy = accuracy_score(y_test, y_pred_test)

    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_scores = cross_val_score(model, x_train, y_train, cv=cv, scoring='accuracy')

    return {
        'Train Accuracy': train_accuracy,
        'Test Accuracy': test_accuracy,
        'CV Mean Score': np.mean(cv_scores),
        'CV Std Dev': np.std(cv_scores)
    }

# Evaluate each model and store results
for model_name, model in models.items():
    metrics = evaluate_model(model, x_train, y_train, x_test, y_test)
    metrics['Model'] = model_name
    results.append(metrics)

# Create a DataFrame from the results
metrics_df = pd.DataFrame(results)

# Display results
print(metrics_df)

# Determine the best model based on the highest test accuracy
best_model_name = metrics_df.loc[metrics_df['Test Accuracy'].idxmax()]['Model']
print(f"\nBest Model: {best_model_name}\n")
# Out:
#    Train Accuracy  Test Accuracy  CV Mean Score  CV Std Dev  \
# 0        1.000000       1.000000       0.930556    0.068324
# 1        0.975000       0.966667       0.958333    0.063647
# 2        0.925000       0.966667       0.916667    0.074536
# 3        0.958333       1.000000       0.950000    0.055277
# 4        0.975000       1.000000       0.955556    0.055833
# 5        0.950000       1.000000       0.941667    0.065085
#
#                  Model
# 0        Random Forest
# 1                  MLP
# 2  Logistic Regression
# 3                  KNN
# 4                  SVM
# 5          Naive Bayes
#
# Best Model: Random Forest

# %% [markdown]
# ## Model Comparison Insights 🎯
#
# |    | Train Accuracy | Test Accuracy | CV Mean Score | CV Std Dev | Model                |
# |----|----------------|---------------|---------------|------------|----------------------|
# | 0  | 1.000000       | 1.000000      | 0.927778      | 0.059835   | Random Forest        |
# | 1  | 0.975000       | 0.966667      | 0.961111      | 0.063586   | MLP                  |
# | 2  | 0.925000       | 0.966667      | 0.911111      | 0.074328   | Logistic Regression  |
# | 3  | 0.966667       | 1.000000      | 0.938889      | 0.067814   | KNN                  |
# | 4  | 0.975000       | 1.000000      | 0.961111      | 0.051520   | SVM                  |
# | 5  | 0.950000       | 1.000000      | 0.941667      | 0.065085   | Naive Bayes          |
#
# **Insights:**
# - `Random Forest` achieved the **highest mean cross-validation score of 0.927778**, indicating strong performance across different folds.
# - **MLP (Multilayer Perceptron)** also performed well with a **mean cross-validation score of 0.961111**, closely followed by **SVM (Support Vector Machine)** and **Naive Bayes**.
# - **Logistic Regression** had the lowest **mean cross-validation score of 0.911111**, suggesting slightly weaker performance compared to other models.
# - **Random Forest** is identified as the `best model` based on the highest mean cross-validation score among all models.

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 8. |  Predictions (2-Ways) 📉</p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 8.1 | Manual Way</p></div>

# %%
# Define a dictionary to store results for all models
results = {}

# Make predictions for each model
for model_name, model in zip(['RandomForest', 'MLP', 'LogisticRegression', 'KNN', 'SVM', 'Naive_Bayes'], [rf, mlp, lr, knn, svm, naive_bayes]):
    # Make predictions on the test set
    y_pred = model.predict(x_test)
    
    # Create a DataFrame with selected features and predictions
    result_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
    
    # Reset index to remove default index
    result_df.reset_index(drop=True, inplace=True)

    # Store the result DataFrame in the results dictionary
    results[model_name] = result_df

# Display only 7 values for each model
for model_name, result_df in results.items():
    print(f"Results for {model_name}:\n")
    print(result_df.head(7).to_string(index=False))  # Use head(7) to display only 7 rows
    print('*' * 80, "\n")
# Out:
# Results for RandomForest:
#
#  Actual  Predicted
#       1          1
#       0          0
#       2          2
#       1          1
#       1          1
#       0          0
#       1          1
# ********************************************************************************
#
# Results for MLP:
#
#  Actual  Predicted
#       1          1
#       0          0
#       2          2
#       1          1
#       1          1
#       0          0
#       1          1
# ********************************************************************************
#
# Results for LogisticRegression:
#
#  Actual  Predicted
#       1          1
#       0          0
#       2          2
#       1          1
#       1          1
#       0          0
#       1          1
# ********************************************************************************
#
# Results for KNN:
#
#  Actual  Predicted
#       1          1
#       0          0
#       2          2
#       1          1
#       1          1
# ...

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b>8.2 | User-Defined Way</p></div>

# %%
def predict_iris_species(model, input_data):
    # Make prediction using the model
    prediction = model.predict([input_data])
    # Convert the predicted species index to actual species name
    species_mapping = {0: 'Iris-setosa', 1: 'Iris-versicolor', 2: 'Iris-virginica'}
    predicted_species = species_mapping[prediction[0]]
    # Return the predicted species
    return predicted_species

model = svm  # Assuming you have a trained Random Forest model

# Function to take input from the user
def get_user_input():
    sepal_length = float(input("Enter Sepal Length: "))
    sepal_width = float(input("Enter Sepal Width: "))
    petal_length = float(input("Enter Petal Length: "))
    petal_width = float(input("Enter Petal Width: "))

    # Convert input data to a list
    input_data_as_list = [sepal_length, sepal_width, petal_length, petal_width]

    return input_data_as_list

# Get input data from the user
input_data = get_user_input()

# Predict the species
predicted_species = predict_iris_species(model, input_data)

# Print the predicted species
print("Predicted Iris Species:", predicted_species)


#0.5	0.375	0.508474576	0.5
# Out:
# Enter Sepal Length: 0.5
# Enter Sepal Width: 0.38
# Enter Petal Length: 0.5
# Enter Petal Width: 0.5
# Predicted Iris Species: Iris-versicolor

# %%
def predict_iris_species(model, input_data):
    # Make prediction using the model
    prediction = model.predict([input_data])
    # Convert the predicted species index to actual species name
    species_mapping = {0: 'Iris-setosa', 1: 'Iris-versicolor', 2: 'Iris-virginica'}
    predicted_species = species_mapping[prediction[0]]
    # Return the predicted species
    return predicted_species

model = rf  # Assuming you have a trained Random Forest model

# Function to take input from the user
def get_user_input():
    sepal_length = float(input("Enter Sepal Length: "))
    sepal_width = float(input("Enter Sepal Width: "))
    petal_length = float(input("Enter Petal Length: "))
    petal_width = float(input("Enter Petal Width: "))

    # Convert input data to a list
    input_data_as_list = [sepal_length, sepal_width, petal_length, petal_width]

    return input_data_as_list

# Get input data from the user
input_data = get_user_input()

# Predict the species
predicted_species = predict_iris_species(model, input_data)

# Print the predicted species
print("Predicted Iris Species:", predicted_species)


#0.5	0.375	0.508474576	0.5
# Out:
# Enter Sepal Length: 0.5
# Enter Sepal Width: 0.38
# Enter Petal Length: 0.5
# Enter Petal Width: 0.5
# Predicted Iris Species: Iris-versicolor

# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#7D3C98;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 10. | Saving Models 🧪 </p></div>

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 10.1 | Best Model</p></div>

# %%
import joblib
joblib_file = "RandomForest_model.pkl"
joblib.dump(rf, joblib_file)
print(f"Model saved as {joblib_file}")

# Load the model using joblib
loaded_model = joblib.load(joblib_file)
print("Model loaded.")

# Evaluate the loaded model
result = loaded_model.score(x_test, y_test)
print(f"Model accuracy: {result}")
# Out:
# Model saved as RandomForest_model.pkl
# Model loaded.
# Model accuracy: 1.0

# %% [markdown]
# ### <div style="color:white;display:fill;border-radius:5px;background-color:#000000;padding:10px;letter-spacing:0.5px;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;margin:0;font-size:110%"><b></b> 10.2 | 2nd Best Model</p></div>

# %%
import joblib
joblib_file = "SVM_model.pkl"
joblib.dump(svm, joblib_file)
print(f"Model saved as {joblib_file}")

# Load the model using joblib
svm_model = joblib.load(joblib_file)
print("Model loaded.")

# Evaluate the loaded model
result = svm_model.score(x_test, y_test)
print(f"Model accuracy: {result}")
# Out:
# Model saved as SVM_model.pkl
# Model loaded.
# Model accuracy: 1.0
